# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.feature_extraction import DictVectorizer

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Loading and Overviewing of Dataset

# %%
data = pd.read_csv("Dataset/loan_data.csv")
## 
df = data.copy()

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001003   Male     Yes          1      Graduate            No
# 1  LP001005   Male     Yes          0      Graduate           Yes
# 2  LP001006   Male     Yes          0  Not Graduate            No
# 3  LP001008   Male      No          0      Graduate            No
# 4  LP001013   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             4583             1508.0       128.0             360.0
# 1             3000                0.0        66.0             360.0
# 2             2583             2358.0       120.0             360.0
# 3             6000                0.0       141.0             360.0
# 4             2333             1516.0        95.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0         Urban           Y
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df.tail().T
# Out:
#                         376       377       378       379        380
# Loan_ID            LP002953  LP002974  LP002978  LP002979   LP002990
# Gender                 Male      Male    Female      Male     Female
# Married                 Yes       Yes        No       Yes         No
# Dependents               3+         0         0        3+          0
# Education          Graduate  Graduate  Graduate  Graduate   Graduate
# Self_Employed            No        No        No        No        Yes
# ApplicantIncome        5703      3232      2900      4106       4583
# CoapplicantIncome       0.0    1950.0       0.0       0.0        0.0
# LoanAmount            128.0     108.0      71.0      40.0      133.0
# Loan_Amount_Term      360.0     360.0     360.0     180.0      360.0
# Credit_History          1.0       1.0       1.0       1.0        0.0
# Property_Area         Urban     Rural     Rural     Rural  Semiurban
# Loan_Status               Y         Y         Y         Y          N

# %%
print(f'total number of rows: {df.shape[0]} => total number of columns: {df.shape[1]}')
# Out:
# total number of rows: 381 => total number of columns: 13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            381 non-null    object
#  1   Gender             376 non-null    object
#  2   Married            381 non-null    object
#  3   Dependents         373 non-null    object
#  4   Education          381 non-null    object
#  5   Self_Employed      360 non-null    object
#  6   ApplicantIncome    381 non-null    int64
#  7   CoapplicantIncome  381 non-null    float64
#  8   LoanAmount         381 non-null    float64
#  9   Loan_Amount_Term   370 non-null    float64
#  10  Credit_History     351 non-null    float64
#  11  Property_Area      381 non-null    object
#  12  Loan_Status        381 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 38.8+ KB

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                5
# Married               0
# Dependents            8
# Education             0
# Self_Employed        21
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     11
# Credit_History       30
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ## Data Preprocessing - Step 1
# - Normalize the column names
# - Droping the ID column
# - Removing the (+) sign on the Dependants column
# - Fill the NaN in the (Dependants, Credit_History, Loan_Amount, Gender, Self_Employed) columns
# - Replacing categorical columns(Gender, Married, Self-Employed, Education, Property Area, Loan-Status) with integers

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['loan_id', 'gender', 'married', 'dependents', 'education',
#        'self_employed', 'applicantincome', 'coapplicantincome', 'loanamount',
#        'loan_amount_term', 'credit_history', 'property_area', 'loan_status'],
#       dtype='object')

# %%
df = df.drop(['loan_id'], axis=1)

# %%
## remove + from the dependents column
df['dependents'] = df['dependents'].str.replace('+', '')

# %%
## convert the dependents column type to integer
df['dependents'] = df['dependents'].astype('float')

# %%
df['dependents'].isnull().sum()
# Out:
# 8

# %%
df['dependents'] = df['dependents'].fillna(df['dependents'].mean())

# %%
df['credit_history'] = df['credit_history'].fillna(df['credit_history'].mean())

# %%
df['loan_amount_term'] = df['loan_amount_term'].fillna(df['loan_amount_term'].mean())

# %%
## target variable 
df.gender.value_counts()
# Out:
# gender
# Male      291
# Female     85
# Name: count, dtype: int64

# %%
df.gender = df.gender.fillna("Male")

# %%
## target variable 
df.self_employed.value_counts()
# Out:
# self_employed
# No     325
# Yes     35
# Name: count, dtype: int64

# %%
df.self_employed = df.self_employed.fillna("No")

# %%
df.isnull().sum()
# Out:
# gender               0
# married              0
# dependents           0
# education            0
# self_employed        0
# applicantincome      0
# coapplicantincome    0
# loanamount           0
# loan_amount_term     0
# credit_history       0
# property_area        0
# loan_status          0
# dtype: int64

# %%
df.dtypes
# Out:
# gender                object
# married               object
# dependents           float64
# education             object
# self_employed         object
# applicantincome        int64
# coapplicantincome    float64
# loanamount           float64
# loan_amount_term     float64
# credit_history       float64
# property_area         object
# loan_status           object
# dtype: object

# %%
df.loan_status.head()
# Out:
# 0    N
# 1    Y
# 2    Y
# 3    Y
# 4    Y
# Name: loan_status, dtype: object

# %%
df.loan_status = (df.loan_status == 'Y').astype(int)

# %%
df.loan_status.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: loan_status, dtype: int32

# %%
df.head()
# Out:
#   gender married  dependents     education self_employed  applicantincome  \
# 0   Male     Yes         1.0      Graduate            No             4583
# 1   Male     Yes         0.0      Graduate           Yes             3000
# 2   Male     Yes         0.0  Not Graduate            No             2583
# 3   Male      No         0.0      Graduate            No             6000
# 4   Male     Yes         0.0  Not Graduate            No             2333
#
#    coapplicantincome  loanamount  loan_amount_term  credit_history  \
# 0             1508.0       128.0             360.0             1.0
# 1                0.0        66.0             360.0             1.0
# 2             2358.0       120.0             360.0             1.0
# 3                0.0       141.0             360.0             1.0
# 4             1516.0        95.0             360.0             1.0
#
#   property_area  loan_status
# 0         Rural            0
# 1         Urban            1
# 2         Urban            1
# 3         Urban            1
# 4         Urban            1

# %% [markdown]
# ## Exploratory Data Analysis

# %%
## target variable 
df.loan_status.value_counts()
# Out:
# loan_status
# 1    271
# 0    110
# Name: count, dtype: int64

# %%
numeric_cols = df.select_dtypes(exclude=[object])

corr_matrix = numeric_cols.corr()

corr_matrix['loan_status']
# Out:
# dependents           0.006977
# applicantincome     -0.010167
# coapplicantincome    0.009017
# loanamount           0.041220
# loan_amount_term    -0.046807
# credit_history       0.601881
# loan_status          1.000000
# Name: loan_status, dtype: float64

# %% [markdown]
# ## Data Preprocessing - Step 2

# %% [markdown]
# ## Build a Validation Framework

# %%
## 
df_train_full , df_test = train_test_split(df, test_size=0.2, random_state=11) 
df_train, df_valid = train_test_split(df_train_full, test_size=0.25, random_state=11)


print(f'Training dataset: {len(df_train)}')
print(f'Validation dataset: {len(df_valid)}')
print(f'Test dataset: {len(df_test)}')
# Out:
# Training dataset: 228
# Validation dataset: 76
# Test dataset: 77

# %%
y_train = df_train['loan_status'].values
y_valid = df_valid['loan_status'].values
y_test = df_test['loan_status'].values

# %%
del df_train['loan_status']
del df_valid['loan_status']
del df_test['loan_status']

# %% [markdown]
# ## Feature Engineering
# - Dividing our data into numerical and categorical
# - perform the one-hot encoding

# %%
numerical_features = ['dependents','applicantincome','coapplicantincome','loanamount','loan_amount_term','credit_history']

categorical_features = ['gender','married','education','self_employed','property_area']

# %%
## convert the dataframe to into dict
train_dict = df_train[categorical_features + numerical_features].to_dict(orient='records')

valid_dict = df_valid[categorical_features + numerical_features].to_dict(orient='records')

# %%
dv = DictVectorizer(sparse=False)
dv.fit(train_dict)
# Out:
# DictVectorizer(sparse=False)

# %%
X_train = dv.transform(train_dict)

X_valid = dv.transform(valid_dict)

# %% [markdown]
# ## Training The Model

# %%
model = LogisticRegression(solver='liblinear', random_state=1)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=1, solver='liblinear')

# %%
y_valid_pred = model.predict_proba(X_valid)

# %%
y_valid_pred
# Out:
# array([[0.29904901, 0.70095099],
#        [0.05349974, 0.94650026],
#        [0.09855407, 0.90144593],
#        [0.05139747, 0.94860253],
#        [0.22603381, 0.77396619],
#        [0.24613695, 0.75386305],
#        [0.86618202, 0.13381798],
#        [0.03618916, 0.96381084],
#        [0.35077405, 0.64922595],
#        [0.94732957, 0.05267043],
#        [0.2595941 , 0.7404059 ],
#        [0.31193893, 0.68806107],
#        [0.06307527, 0.93692473],
#        [0.26280233, 0.73719767],
#        [0.10301751, 0.89698249],
#        [0.15404105, 0.84595895],
#        [0.46010115, 0.53989885],
#        [0.28356447, 0.71643553],
#        [0.06021712, 0.93978288],
#        [0.04764756, 0.95235244],
#        [0.36715074, 0.63284926],
#        [0.17712346, 0.82287654],
#        [0.09271481, 0.90728519],
#        [0.13391169, 0.86608831],
#        [0.38108233, 0.61891767],
#        [0.3513784 , 0.6486216 ],
#        [0.48530569, 0.51469431],
#        [0.23176625, 0.76823375],
#        [0.27767248, 0.72232752],
#        [0.05152199, 0.94847801],
#        [0.05281199, 0.94718801],
#        [0.09515649, 0.90484351],
#        [0.01167357, 0.98832643],
#        [0.38402706, 0.61597294],
#        [0.85744356, 0.14255644],
#        [0.26409142, 0.73590858],
#        [0.41226824, 0.58773176],
#        [0.04138121, 0.95861879],
#        [0.05399322, 0.94600678],
#        [0.16846212, 0.83153788],
#        [0.25406587, 0.74593413],
#        [0.21162241, 0.78837759],
#        [0.08188626, 0.91811374],
#        [0.02396884, 0.97603116],
#        [0.07433011, 0.92566989],
#        [0.80379633, 0.19620367],
#        [0.02401395, 0.97598605],
#        [0.09346341, 0.90653659],
#        [0.43681536, 0.56318464],
#        [0.26270284, 0.73729716],
#        [0.70592747, 0.29407253],
#        [0.17824992, 0.82175008],
#        [0.92766715, 0.07233285],
#        [0.29255158, 0.70744842],
#        [0.07111961, 0.92888039],
#        [0.05936526, 0.94063474],
#        [0.08755133, 0.91244867],
#        [0.05807359, 0.94192641],
#        [0.09502729, 0.90497271],
#        [0.94028022, 0.05971978],
#        [0.31333712, 0.68666288],
#        [0.24491291, 0.75508709],
#        [0.12875471, 0.87124529],
#        [0.16715322, 0.83284678],
#        [0.03926609, 0.96073391],
#        [0.24962587, 0.75037413],
#        [0.31670624, 0.68329376],
#        [0.21161671, 0.78838329],
#        [0.01935651, 0.98064349],
#        [0.10974382, 0.89025618],
#        [0.28644595, 0.71355405],
#        [0.14446698, 0.85553302],
#        [0.18281265, 0.81718735],
#        [0.11965224, 0.88034776],
#        [0.22740784, 0.77259216],
#        [0.06626309, 0.93373691]])

# %%
y_valid_pred = model.predict_proba(X_valid)[:, 1]

# %%
loan_status = y_valid_pred >= 0.5

# %%
(y_valid == loan_status).mean()
# Out:
# 0.881578947368421

# %%
acc_score = accuracy_score(y_valid, loan_status)
print(f'Validation Accuracy Score: {round(acc_score * 100, 1)}%')
# Out:
# Validation Accuracy Score: 88.2%

# %% [markdown]
# ## Saving The Model

# %%
import pickle

# %%
## specifyging where to save the file
with open('loan-model.bin', 'wb') as f_out:
    ## save the model
    pickle.dump((dv,model), f_out)

# %% [markdown]
# ## Loading The Model

# %%
with open('loan-model.bin', 'rb') as f_in:
    dv, model = pickle.load(f_in)

# %%
## applicant Data here
applicant = {
 'customerid': 0,
 'gender': 'Male',
 'married': 'Yes',
 'dependents': 1.0,
 'education': 'Graduate',
 'self_employed': 'No',    
 'applicantincome': 4583,
 'coapplicantincome': 1508.0,
 'loanamount': 128.0,
 'loan_amount_term': 360.0,
 'credit_history': 1.0,
 'property_area': 'Rural', 
}

# %%
def predict_single(df, dv, model):
    X = dv.transform([applicant])
    y_pred = model.predict_proba(X)[:,1]
    return y_pred[0]

# %%
prediction = predict_single(applicant, dv, model)

# %%
print(f'{prediction}')
# Out:
# 0.7754906290999604

# %%
if prediction >= 0.5:
    print('verdict: Good standing - "Approve"')
else:
    print('verdict: Bad standing - "Reject"')
# Out:
# verdict: Good standing - "Approve"
